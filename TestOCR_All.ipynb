# %% [markdown]
# # EasyOCR 종합 테스트

# %% [markdown]
# 테스트 결과만 출력

# %% [markdown]
# ## readtext
# 속도, 정확도 측정 / 결과물 저장

# %%
import easyocr
import json
import os
import time

import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image

# 폴더 경로
folder_path_source = '2001_source'
folder_path_label = '2001_label'

# 폴더 안에 있는 모든 파일을 리스트 형태로 가져오기
file_list = os.listdir(folder_path_source)

# 파일 경로와 파일 이름 결합
file_paths = [os.path.join(folder_path_source, file_name) for file_name in file_list]

# 파일 수와 평균 경과 시간, 평균 정확도를 저장할 변수 초기화
file_count = len(file_paths)
total_elapsed_time = 0
total_accuracy = 0

'''
# 파일 개수 지정 (ex) 1개)
file_paths = file_paths[:1]
file_count = 1
'''

# easyocr 모델 로드
reader = easyocr.Reader(['ko','en'], gpu=True)

# 각 파일에 대해 OCR 수행
for file_path in file_paths:
    filename_split = os.path.splitext(os.path.basename(file_path))[0]
    print("파일명 :", os.path.basename(file_path))
    print("인식 실행 중")
    
    # 시작 시간 저장
    start_time = time.time()
    
    # OCR 인식 결과 추출
    result = reader.readtext(folder_path_source+"/"+filename_split+".jpg", width_ths=0.1, adjust_contrast=0.1)
    
    # 인식 경과 시간 계산
    elapsed_time = time.time() - start_time
    
    # 총 경과 시간 계산
    total_elapsed_time += elapsed_time
    
    '''
    # 문자 인식 결과 출력
    print("")
    print("<EasyOCR 인식 결과>")
    print(result)
    
    print("")
    print("<EasyOCR 좌표 값 인덱싱>")
    # 좌표 값만 출력 (인덱싱)
    for i in result:
        print(i[0])
    '''
    
    # 라벨링 데이터(json) 파일 불러오기
    with open(folder_path_label+"/"+filename_split+".json", encoding="UTF8") as file:
        data = json.load(file)
        json_test = data['annotations']
        
        '''
        # 라벨링 데이터의 좌표 값만 출력
        print("")
        print("<라벨링 데이터>")
        for k in json_test:
            print(k['annotation.bbox'])
        '''
        
    # 인식 결과값과 라벨링 데이터 값 추출
    result_texts = {i[1] for i in result}
    json_test_texts = {k['annotation.text'] for k in json_test}
    
    result_list = []
    json_test_list = []
    matching_texts = []
        
    # 인식한 문자를 한 글자씩 분리
    for text_result in sorted(result_texts):
        result_list.extend(list(text_result))
    for text_json in sorted(json_test_texts):
        json_test_list.extend(list(text_json))
        
    '''
    # 분리 결과 출력
    print("")
    print("<인식한 문자 분리 결과>")
    print(result_list)
    print("[분리한 인식 문자] : 총 "+str(len(result_list))+"개")
    print("")
    print("<라벨링 문자 분리 결과>")
    print(json_test_list)
    print("[분리한 라벨링 문자] : 총 "+str(len(json_test_list))+"개")
    '''
    
    # 한 글자씩 비교하여 일치하는 값을 matching_texts 리스트에 저장
    for item in result_list:
        if item in json_test_list:
            matching_texts.append(item)
        
    '''
    # 일치 문자 출력
    print("")
    print("<일치 문자 결과>")
    print(matching_texts)
    print("[일치한 문자] : 총 "+str(len(matching_texts))+"개")
    print("")
    '''

    # 정확도 계산
    percentage = (len(matching_texts) / len(result_list)) * 100
    
    # 정확도, 경과 시간 출력
    if matching_texts:
        print("정확도 : {:.2f}%".format(percentage))
        print("경과 시간 : {:.2f}초".format(elapsed_time))
        total_accuracy += percentage
    else:
        print("정확한 인식 값이 없습니다.")
            
    print("")
    
    # 인식 결과 출력
    img = cv2.imread(folder_path_source+"/"+filename_split+".jpg")

    img = Image.fromarray(img)    # 이미지에 그리기 위해서 CV2 이미지를 PIL 이미지 객체로 변환
    draw = ImageDraw.Draw(img)

    np.random.seed(42)
    COLORS = np.random.randint(0, 255, size=(255, 3),dtype="uint8")

    for i in result :
        # 이미지 좌표 변수 지정
        x = i[0][0][0] 
        y = i[0][0][1] 
        w = i[0][1][0] - i[0][0][0] 
        h = i[0][2][1] - i[0][1][1]
    
        # 랜덤 색상 지정
        color_idx = random.randint(0,254)
        color = [int(c) for c in COLORS[color_idx]]

        # 이미지에 인식 영역 / 인식 문자 출력
        draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2)

    '''
    plt.figure(figsize=(50,50))
    plt.imshow(img)
    plt.show()
    '''
    
    img.save('ResultImage_readtext/'+filename_split+'_result(readtext).jpg')  # JPG 형식으로 저장

# 총 데이터 수 및 총 소요시간, 평균 경과 시간, 평균 정확도 계산
average_elapsed_time = total_elapsed_time / file_count
average_accuracy = total_accuracy / file_count
total_minutes = int(total_elapsed_time // 60)
total_seconds = int(total_elapsed_time % 60)

# 테스트 결과 출력
print("<테스트 총 결과>")
print("총 데이터 수 : "+str(file_count)+"개")
print("총 소요 시간 : "+str(total_minutes)+"분 "+str(total_seconds)+"초")
print("평균 인식 시간 : {:.2f}초".format(average_elapsed_time))
print("평균 정확도 : {:.2f}%".format(average_accuracy))
# Out:
# 파일명 : 5350109-2001-0001-0001.jpg
# 인식 실행 중
# 정확도 : 96.44%
# 경과 시간 : 2.90초
#
# 파일명 : 5350109-2001-0001-0002.jpg
# 인식 실행 중
# 정확도 : 84.35%
# 경과 시간 : 2.38초
#
# 파일명 : 5350109-2001-0001-0004.jpg
# 인식 실행 중
# 정확도 : 96.22%
# 경과 시간 : 3.13초
#
# 파일명 : 5350109-2001-0001-0005.jpg
# 인식 실행 중
# 정확도 : 95.25%
# 경과 시간 : 2.61초
#
# 파일명 : 5350109-2001-0001-0006.jpg
# 인식 실행 중
# 정확도 : 81.13%
# 경과 시간 : 1.33초
#
# 파일명 : 5350109-2001-0001-0009.jpg
# 인식 실행 중
# 정확도 : 96.73%
# 경과 시간 : 2.94초
#
# 파일명 : 5350109-2001-0001-0010.jpg
# 인식 실행 중
# 정확도 : 97.00%
# 경과 시간 : 2.82초
#
# 파일명 : 5350109-2001-0001-0015.jpg
# 인식 실행 중
# 정확도 : 95.68%
# 경과 시간 : 4.64초
#
# 파일명 : 5350109-2001-0001-0016.jpg
# 인식 실행 중
# 정확도 : 72.73%
# 경과 시간 : 1.53초
#
# 파일명 : 5350109-2001-0001-0017.jpg
# 인식 실행 중
# 정확도 : 94.14%
# 경과 시간 : 3.55초
#
# 파일명 : 5350109-2001-0001-0018.jpg
# 인식 실행 중
# 정확도 : 96.81%
# 경과 시간 : 2.77초
#
# 파일명 : 5350109-2001-0001-0019.jpg
# 인식 실행 중
# 정확도 : 73.86%
# 경과 시간 : 1.03초
#
# 파일명 : 5350109-2001-0001-0020.jpg
# 인식 실행 중
# 정확도 : 95.91%
# 경과 시간 : 3.46초
#
# 파일명 : 5350109-2001-0001-0021.jpg
# 인식 실행 중
# 정확도 : 95.32%
# 경과 시간 : 2.15초
#
# 파일명 : 5350109-2001-0001-0022.jpg
# 인식 실행 중
# 정확도 : 88.35%
# 경과 시간 : 2.39초
#
# 파일명 : 5350109-2001-0001-0023.jpg
# 인식 실행 중
# 정확도 : 93.57%
# 경과 시간 : 3.30초
#
# 파일명 : 5350109-2001-0001-0024.jpg
# 인식 실행 중
# 정확도 : 81.90%
# 경과 시간 : 2.67초
#
# 파일명 : 5350109-2001-0001-0028.jpg
# 인식 실행 중
# 정확도 : 95.32%
# 경과 시간 : 5.35초
#
# 파일명 : 5350109-2001-0001-0029.jpg
# 인식 실행 중
# 정확도 : 97.80%
# 경과 시간 : 1.47초
#
# 파일명 : 5350109-2001-0001-0030.jpg
# 인식 실행 중
# 정확도 : 95.69%
# 경과 시간 : 2.88초
#
# 파일명 : 5350109-2001-0001-0031.jpg
# 인식 실행 중
# 정확도 : 85.86%
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0033.jpg
# 인식 실행 중
# 정확도 : 76.29%
# 경과 시간 : 0.97초
#
# 파일명 : 5350109-2001-0001-0034.jpg
# 인식 실행 중
# 정확도 : 94.57%
# 경과 시간 : 4.90초
#
# 파일명 : 5350109-2001-0001-0035.jpg
# 인식 실행 중
# 정확도 : 73.23%
# 경과 시간 : 1.36초
#
# 파일명 : 5350109-2001-0001-0036.jpg
# 인식 실행 중
# 정확도 : 85.65%
# 경과 시간 : 3.09초
#
# 파일명 : 5350109-2001-0001-0038.jpg
# 인식 실행 중
# 정확도 : 97.00%
# 경과 시간 : 4.17초
#
# 파일명 : 5350109-2001-0001-0039.jpg
# 인식 실행 중
# 정확도 : 94.55%
# 경과 시간 : 2.63초
#
# 파일명 : 5350109-2001-0001-0040.jpg
# 인식 실행 중
# 정확도 : 95.37%
# 경과 시간 : 4.06초
#
# 파일명 : 5350109-2001-0001-0041.jpg
# 인식 실행 중
# 정확도 : 75.29%
# 경과 시간 : 1.02초
#
# 파일명 : 5350109-2001-0001-0042.jpg
# 인식 실행 중
# 정확도 : 93.83%
# 경과 시간 : 3.26초
#
# 파일명 : 5350109-2001-0001-0043.jpg
# 인식 실행 중
# 정확도 : 96.39%
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0044.jpg
# 인식 실행 중
# 정확도 : 94.06%
# 경과 시간 : 2.46초
#
# 파일명 : 5350109-2001-0001-0045.jpg
# 인식 실행 중
# 정확도 : 93.30%
# 경과 시간 : 1.75초
#
# 파일명 : 5350109-2001-0001-0049.jpg
# 인식 실행 중
# 정확도 : 93.79%
# 경과 시간 : 2.07초
#
# 파일명 : 5350109-2001-0001-0050.jpg
# 인식 실행 중
# 정확도 : 93.63%
# 경과 시간 : 1.49초
#
# 파일명 : 5350109-2001-0001-0101.jpg
# 인식 실행 중
# 정확도 : 94.82%
# 경과 시간 : 2.31초
#
# 파일명 : 5350109-2001-0001-0102.jpg
# 인식 실행 중
# 정확도 : 73.08%
# 경과 시간 : 1.06초
#
# 파일명 : 5350109-2001-0001-0103.jpg
# 인식 실행 중
# 정확도 : 96.52%
# 경과 시간 : 3.03초
#
# 파일명 : 5350109-2001-0001-0104.jpg
# 인식 실행 중
# 정확도 : 95.57%
# 경과 시간 : 2.80초
#
# 파일명 : 5350109-2001-0001-0105.jpg
# 인식 실행 중
# 정확도 : 96.05%
# 경과 시간 : 1.06초
#
# 파일명 : 5350109-2001-0001-0106.jpg
# 인식 실행 중
# 정확도 : 88.09%
# 경과 시간 : 2.69초
#
# 파일명 : 5350109-2001-0001-0107.jpg
# 인식 실행 중
# 정확도 : 75.00%
# 경과 시간 : 2.85초
#
# 파일명 : 5350109-2001-0001-0118.jpg
# 인식 실행 중
# 정확도 : 95.95%
# 경과 시간 : 2.93초
#
# 파일명 : 5350109-2001-0001-0119.jpg
# 인식 실행 중
# 정확도 : 97.35%
# 경과 시간 : 1.17초
#
# 파일명 : 5350109-2001-0001-0120.jpg
# 인식 실행 중
# 정확도 : 94.92%
# 경과 시간 : 2.43초
#
# 파일명 : 5350109-2001-0001-0121.jpg
# 인식 실행 중
# 정확도 : 94.40%
# 경과 시간 : 3.09초
#
# 파일명 : 5350109-2001-0001-0122.jpg
# 인식 실행 중
# 정확도 : 95.48%
# 경과 시간 : 1.75초
#
# 파일명 : 5350109-2001-0001-0123.jpg
# 인식 실행 중
# 정확도 : 96.13%
# 경과 시간 : 4.32초
#
# 파일명 : 5350109-2001-0001-0124.jpg
# 인식 실행 중
# 정확도 : 57.47%
# 경과 시간 : 0.78초
#
# 파일명 : 5350109-2001-0001-0125.jpg
# 인식 실행 중
# 정확도 : 94.78%
# 경과 시간 : 2.73초
#
# 파일명 : 5350109-2001-0001-0126.jpg
# 인식 실행 중
# 정확도 : 94.85%
# 경과 시간 : 2.53초
#
# 파일명 : 5350109-2001-0001-0129.jpg
# 인식 실행 중
# 정확도 : 95.22%
# 경과 시간 : 2.91초
#
# 파일명 : 5350109-2001-0001-0130.jpg
# 인식 실행 중
# 정확도 : 95.37%
# 경과 시간 : 3.71초
#
# 파일명 : 5350109-2001-0001-0131.jpg
# 인식 실행 중
# 정확도 : 94.55%
# 경과 시간 : 2.85초
#
# 파일명 : 5350109-2001-0001-0132.jpg
# 인식 실행 중
# 정확도 : 93.16%
# 경과 시간 : 1.57초
#
# 파일명 : 5350109-2001-0001-0133.jpg
# 인식 실행 중
# 정확도 : 85.69%
# 경과 시간 : 2.58초
#
# 파일명 : 5350109-2001-0001-0134.jpg
# 인식 실행 중
# 정확도 : 94.12%
# 경과 시간 : 2.64초
#
# 파일명 : 5350109-2001-0001-0135.jpg
# 인식 실행 중
# 정확도 : 95.71%
# 경과 시간 : 3.02초
#
# 파일명 : 5350109-2001-0001-0136.jpg
# 인식 실행 중
# 정확도 : 97.20%
# 경과 시간 : 2.02초
#
# 파일명 : 5350109-2001-0001-0137.jpg
# 인식 실행 중
# 정확도 : 95.45%
# 경과 시간 : 2.57초
#
# 파일명 : 5350109-2001-0001-0138.jpg
# 인식 실행 중
# 정확도 : 96.21%
# 경과 시간 : 1.79초
#
# 파일명 : 5350109-2001-0001-0139.jpg
# 인식 실행 중
# 정확도 : 95.26%
# 경과 시간 : 3.30초
#
# 파일명 : 5350109-2001-0001-0140.jpg
# 인식 실행 중
# 정확도 : 94.84%
# 경과 시간 : 2.12초
#
# 파일명 : 5350109-2001-0001-0141.jpg
# 인식 실행 중
# 정확도 : 93.93%
# 경과 시간 : 2.01초
#
# 파일명 : 5350109-2001-0001-0144.jpg
# 인식 실행 중
# 정확도 : 95.07%
# 경과 시간 : 2.67초
#
# 파일명 : 5350109-2001-0001-0145.jpg
# 인식 실행 중
# 정확도 : 93.71%
# 경과 시간 : 2.25초
#
# 파일명 : 5350109-2001-0001-0147.jpg
# 인식 실행 중
# 정확도 : 96.36%
# 경과 시간 : 1.58초
#
# 파일명 : 5350109-2001-0001-0155.jpg
# 인식 실행 중
# 정확도 : 95.84%
# 경과 시간 : 1.92초
#
# 파일명 : 5350109-2001-0001-0156.jpg
# 인식 실행 중
# 정확도 : 94.27%
# 경과 시간 : 3.54초
#
# 파일명 : 5350109-2001-0001-0157.jpg
# 인식 실행 중
# 정확도 : 94.68%
# 경과 시간 : 2.03초
#
# 파일명 : 5350109-2001-0001-0170.jpg
# 인식 실행 중
# 정확도 : 95.68%
# 경과 시간 : 2.23초
#
# 파일명 : 5350109-2001-0001-0171.jpg
# 인식 실행 중
# 정확도 : 74.77%
# 경과 시간 : 0.81초
#
# 파일명 : 5350109-2001-0001-0172.jpg
# 인식 실행 중
# 정확도 : 85.25%
# 경과 시간 : 2.73초
#
# 파일명 : 5350109-2001-0001-0173.jpg
# 인식 실행 중
# 정확도 : 78.90%
# 경과 시간 : 3.82초
#
# 파일명 : 5350109-2001-0001-0223.jpg
# 인식 실행 중
# 정확도 : 95.73%
# 경과 시간 : 3.85초
#
# 파일명 : 5350109-2001-0001-0224.jpg
# 인식 실행 중
# 정확도 : 96.54%
# 경과 시간 : 2.14초
#
# 파일명 : 5350109-2001-0001-0225.jpg
# 인식 실행 중
# 정확도 : 97.08%
# 경과 시간 : 3.16초
#
# 파일명 : 5350109-2001-0001-0227.jpg
# 인식 실행 중
# 정확도 : 92.72%
# 경과 시간 : 2.51초
#
# 파일명 : 5350109-2001-0001-0228.jpg
# 인식 실행 중
# 정확도 : 95.13%
# 경과 시간 : 1.11초
#
# 파일명 : 5350109-2001-0001-0230.jpg
# 인식 실행 중
# 정확도 : 96.13%
# 경과 시간 : 2.06초
#
# 파일명 : 5350109-2001-0001-0231.jpg
# 인식 실행 중
# 정확도 : 68.60%
# 경과 시간 : 1.44초
#
# 파일명 : 5350109-2001-0001-0235.jpg
# 인식 실행 중
# 정확도 : 94.26%
# 경과 시간 : 2.51초
#
# 파일명 : 5350109-2001-0001-0239.jpg
# 인식 실행 중
# 정확도 : 95.43%
# 경과 시간 : 2.42초
#
# 파일명 : 5350109-2001-0001-0240.jpg
# 인식 실행 중
# 정확도 : 82.91%
# 경과 시간 : 1.01초
#
# 파일명 : 5350109-2001-0001-0241.jpg
# 인식 실행 중
# 정확도 : 97.07%
# 경과 시간 : 3.20초
#
# 파일명 : 5350109-2001-0001-0242.jpg
# 인식 실행 중
# 정확도 : 72.09%
# 경과 시간 : 1.11초
#
# 파일명 : 5350109-2001-0001-0244.jpg
# 인식 실행 중
# 정확도 : 95.43%
# 경과 시간 : 2.35초
#
# 파일명 : 5350109-2001-0001-0245.jpg
# 인식 실행 중
# 정확도 : 83.33%
# 경과 시간 : 3.19초
#
# 파일명 : 5350109-2001-0001-0249.jpg
# 인식 실행 중
# 정확도 : 79.63%
# 경과 시간 : 2.68초
#
# 파일명 : 5350109-2001-0001-0250.jpg
# 인식 실행 중
# 정확도 : 81.79%
# 경과 시간 : 2.26초
#
# 파일명 : 5350109-2001-0001-0251.jpg
# 인식 실행 중
# 정확도 : 93.53%
# 경과 시간 : 1.79초
#
# 파일명 : 5350109-2001-0001-0252.jpg
# 인식 실행 중
# 정확도 : 96.54%
# 경과 시간 : 2.31초
#
# 파일명 : 5350109-2001-0001-0333.jpg
# 인식 실행 중
# 정확도 : 96.89%
# 경과 시간 : 2.30초
#
# 파일명 : 5350109-2001-0001-0334.jpg
# 인식 실행 중
# 정확도 : 75.70%
# 경과 시간 : 1.57초
#
# 파일명 : 5350109-2001-0001-0340.jpg
# 인식 실행 중
# 정확도 : 84.02%
# 경과 시간 : 2.00초
#
# 파일명 : 5350109-2001-0001-0341.jpg
# 인식 실행 중
# 정확도 : 95.27%
# 경과 시간 : 1.95초
#
# 파일명 : 5350109-2001-0001-0342.jpg
# 인식 실행 중
# 정확도 : 97.84%
# 경과 시간 : 3.25초
#
# 파일명 : 5350109-2001-0001-0343.jpg
# 인식 실행 중
# 정확도 : 95.13%
# 경과 시간 : 2.01초
#
# 파일명 : 5350109-2001-0001-0344.jpg
# 인식 실행 중
# 정확도 : 96.69%
# 경과 시간 : 1.82초
#
# 파일명 : 5350109-2001-0001-0345.jpg
# 인식 실행 중
# 정확도 : 97.50%
# 경과 시간 : 3.74초
#
# 파일명 : 5350109-2001-0001-0355.jpg
# 인식 실행 중
# 정확도 : 95.88%
# 경과 시간 : 3.73초
#
# 파일명 : 5350109-2001-0001-0356.jpg
# 인식 실행 중
# 정확도 : 95.04%
# 경과 시간 : 3.42초
#
# 파일명 : 5350109-2001-0001-0357.jpg
# 인식 실행 중
# 정확도 : 84.71%
# 경과 시간 : 0.82초
#
# 파일명 : 5350109-2001-0001-0358.jpg
# 인식 실행 중
# 정확도 : 95.23%
# 경과 시간 : 2.41초
#
# 파일명 : 5350109-2001-0001-0359.jpg
# 인식 실행 중
# 정확도 : 75.96%
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0360.jpg
# 인식 실행 중
# 정확도 : 95.24%
# 경과 시간 : 2.69초
#
# 파일명 : 5350109-2001-0001-0361.jpg
# 인식 실행 중
# 정확도 : 96.31%
# 경과 시간 : 2.49초
#
# 파일명 : 5350109-2001-0001-0362.jpg
# 인식 실행 중
# 정확도 : 96.54%
# 경과 시간 : 2.24초
#
# 파일명 : 5350109-2001-0001-0363.jpg
# 인식 실행 중
# 정확도 : 94.11%
# 경과 시간 : 2.78초
#
# 파일명 : 5350109-2001-0001-0364.jpg
# 인식 실행 중
# 정확도 : 97.01%
# 경과 시간 : 1.14초
#
# 파일명 : 5350109-2001-0001-0366.jpg
# 인식 실행 중
# 정확도 : 93.37%
# 경과 시간 : 2.80초
#
# 파일명 : 5350109-2001-0001-0367.jpg
# 인식 실행 중
# 정확도 : 96.86%
# 경과 시간 : 3.46초
#
# 파일명 : 5350109-2001-0001-0455.jpg
# 인식 실행 중
# 정확도 : 91.72%
# 경과 시간 : 3.48초
#
# 파일명 : 5350109-2001-0001-0456.jpg
# 인식 실행 중
# 정확도 : 83.14%
# 경과 시간 : 1.47초
#
# 파일명 : 5350109-2001-0001-0457.jpg
# 인식 실행 중
# 정확도 : 95.21%
# 경과 시간 : 2.82초
#
# 파일명 : 5350109-2001-0001-0458.jpg
# 인식 실행 중
# 정확도 : 82.53%
# 경과 시간 : 1.08초
#
# 파일명 : 5350109-2001-0001-0460.jpg
# 인식 실행 중
# 정확도 : 94.81%
# 경과 시간 : 2.57초
#
# 파일명 : 5350109-2001-0001-0461.jpg
# 인식 실행 중
# 정확도 : 96.08%
# 경과 시간 : 2.09초
#
# 파일명 : 5350109-2001-0001-0464.jpg
# 인식 실행 중
# 정확도 : 94.62%
# 경과 시간 : 2.50초
#
# 파일명 : 5350109-2001-0001-0465.jpg
# 인식 실행 중
# 정확도 : 81.63%
# 경과 시간 : 2.26초
#
# 파일명 : 5350109-2001-0001-0466.jpg
# 인식 실행 중
# 정확도 : 96.57%
# 경과 시간 : 2.54초
#
# 파일명 : 5350109-2001-0001-0467.jpg
# 인식 실행 중
# 정확도 : 94.16%
# 경과 시간 : 2.55초
#
# 파일명 : 5350109-2001-0001-0468.jpg
# 인식 실행 중
# 정확도 : 96.65%
# 경과 시간 : 1.82초
#
# 파일명 : 5350109-2001-0001-0469.jpg
# 인식 실행 중
# 정확도 : 95.06%
# 경과 시간 : 4.40초
#
# 파일명 : 5350109-2001-0001-0470.jpg
# 인식 실행 중
# 정확도 : 95.89%
# 경과 시간 : 2.91초
#
# 파일명 : 5350109-2001-0001-0471.jpg
# 인식 실행 중
# 정확도 : 73.56%
# 경과 시간 : 0.78초
#
# 파일명 : 5350109-2001-0001-0472.jpg
# 인식 실행 중
# 정확도 : 94.88%
# 경과 시간 : 3.45초
#
# 파일명 : 5350109-2001-0001-0473.jpg
# 인식 실행 중
# 정확도 : 96.60%
# 경과 시간 : 1.10초
#
# 파일명 : 5350109-2001-0001-0479.jpg
# 인식 실행 중
# 정확도 : 94.32%
# 경과 시간 : 3.79초
#
# 파일명 : 5350109-2001-0001-0480.jpg
# 인식 실행 중
# 정확도 : 80.91%
# 경과 시간 : 2.22초
#
# 파일명 : 5350109-2001-0001-0481.jpg
# 인식 실행 중
# 정확도 : 96.35%
# 경과 시간 : 2.38초
#
# 파일명 : 5350109-2001-0001-0482.jpg
# 인식 실행 중
# 정확도 : 96.53%
# 경과 시간 : 2.67초
#
# 파일명 : 5350109-2001-0001-0483.jpg
# 인식 실행 중
# 정확도 : 73.86%
# 경과 시간 : 0.80초
#
# 파일명 : 5350109-2001-0001-0484.jpg
# 인식 실행 중
# 정확도 : 97.10%
# 경과 시간 : 2.60초
#
# 파일명 : 5350109-2001-0001-0485.jpg
# 인식 실행 중
# 정확도 : 87.07%
# 경과 시간 : 1.90초
#
# 파일명 : 5350109-2001-0001-0598.jpg
# 인식 실행 중
# 정확도 : 96.66%
# 경과 시간 : 4.21초
#
# 파일명 : 5350109-2001-0001-0599.jpg
# 인식 실행 중
# 정확도 : 73.81%
# 경과 시간 : 0.76초
#
# 파일명 : 5350109-2001-0001-0600.jpg
# 인식 실행 중
# 정확도 : 95.39%
# 경과 시간 : 3.10초
#
# 파일명 : 5350109-2001-0001-0601.jpg
# 인식 실행 중
# 정확도 : 96.75%
# 경과 시간 : 2.25초
#
# 파일명 : 5350109-2001-0001-0602.jpg
# 인식 실행 중
# 정확도 : 95.94%
# 경과 시간 : 2.78초
#
# 파일명 : 5350109-2001-0001-0603.jpg
# 인식 실행 중
# 정확도 : 97.31%
# 경과 시간 : 1.34초
#
# 파일명 : 5350109-2001-0001-0604.jpg
# 인식 실행 중
# 정확도 : 97.21%
# 경과 시간 : 2.42초
#
# 파일명 : 5350109-2001-0001-0616.jpg
# 인식 실행 중
# 정확도 : 89.03%
# 경과 시간 : 3.04초
#
# 파일명 : 5350109-2001-0001-0617.jpg
# 인식 실행 중
# 정확도 : 89.40%
# 경과 시간 : 2.68초
#
# 파일명 : 5350109-2001-0001-0618.jpg
# 인식 실행 중
# 정확도 : 96.24%
# 경과 시간 : 3.91초
#
# 파일명 : 5350109-2001-0001-0619.jpg
# 인식 실행 중
# 정확도 : 74.42%
# 경과 시간 : 1.16초
#
# 파일명 : 5350109-2001-0001-0620.jpg
# 인식 실행 중
# 정확도 : 89.88%
# 경과 시간 : 4.63초
#
# 파일명 : 5350109-2001-0001-0621.jpg
# 인식 실행 중
# 정확도 : 98.10%
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0715.jpg
# 인식 실행 중
# 정확도 : 93.41%
# 경과 시간 : 2.52초
#
# 파일명 : 5350109-2001-0001-0716.jpg
# 인식 실행 중
# 정확도 : 96.49%
# 경과 시간 : 2.95초
#
# 파일명 : 5350109-2001-0001-0717.jpg
# 인식 실행 중
# 정확도 : 90.40%
# 경과 시간 : 3.24초
#
# 파일명 : 5350109-2001-0001-0718.jpg
# 인식 실행 중
# 정확도 : 94.23%
# 경과 시간 : 3.34초
#
# 파일명 : 5350109-2001-0001-0719.jpg
# 인식 실행 중
# 정확도 : 91.95%
# 경과 시간 : 3.57초
#
# 파일명 : 5350109-2001-0001-0720.jpg
# 인식 실행 중
# 정확도 : 93.40%
# 경과 시간 : 2.27초
#
# 파일명 : 5350109-2001-0001-0721.jpg
# 인식 실행 중
# 정확도 : 95.13%
# 경과 시간 : 4.08초
#
# 파일명 : 5350109-2001-0001-0722.jpg
# 인식 실행 중
# 정확도 : 97.29%
# 경과 시간 : 2.37초
#
# 파일명 : 5350109-2001-0001-0724.jpg
# 인식 실행 중
# 정확도 : 95.65%
# 경과 시간 : 4.28초
#
# 파일명 : 5350109-2001-0001-0727.jpg
# 인식 실행 중
# 정확도 : 75.61%
# 경과 시간 : 0.77초
#
# 파일명 : 5350109-2001-0001-1088.jpg
# 인식 실행 중
# 정확도 : 96.73%
# 경과 시간 : 2.94초
#
# 파일명 : 5350109-2001-0001-1089.jpg
# 인식 실행 중
# 정확도 : 84.34%
# 경과 시간 : 1.64초
#
# 파일명 : 5350109-2001-0001-1090.jpg
# 인식 실행 중
# 정확도 : 85.38%
# 경과 시간 : 1.91초
#
# 파일명 : 5350109-2001-0001-1102.jpg
# 인식 실행 중
# 정확도 : 95.84%
# 경과 시간 : 2.59초
#
# 파일명 : 5350109-2001-0001-1103.jpg
# 인식 실행 중
# 정확도 : 96.50%
# 경과 시간 : 1.33초
#
# 파일명 : 5350109-2001-0001-1104.jpg
# 인식 실행 중
# 정확도 : 93.13%
# 경과 시간 : 2.92초
#
# 파일명 : 5350109-2001-0001-1105.jpg
# 인식 실행 중
# 정확도 : 93.15%
# 경과 시간 : 1.56초
#
# 파일명 : 5350109-2001-0001-1112.jpg
# 인식 실행 중
# 정확도 : 95.18%
# 경과 시간 : 4.19초
#
# 파일명 : 5350109-2001-0001-1113.jpg
# 인식 실행 중
# 정확도 : 86.53%
# 경과 시간 : 1.20초
#
# 파일명 : 5350109-2001-0001-1114.jpg
# 인식 실행 중
# 정확도 : 95.88%
# 경과 시간 : 2.83초
#
# 파일명 : 5350109-2001-0001-1115.jpg
# 인식 실행 중
# 정확도 : 77.78%
# 경과 시간 : 2.37초
#
# 파일명 : 5350109-2001-0001-1116.jpg
# 인식 실행 중
# 정확도 : 95.70%
# 경과 시간 : 2.96초
#
# 파일명 : 5350109-2001-0001-1117.jpg
# 인식 실행 중
# 정확도 : 97.80%
# 경과 시간 : 3.31초
#
# 파일명 : 5350109-2001-0001-1120.jpg
# 인식 실행 중
# 정확도 : 96.21%
# 경과 시간 : 4.31초
#
# 파일명 : 5350109-2001-0001-1121.jpg
# 인식 실행 중
# 정확도 : 87.56%
# 경과 시간 : 1.64초
#
# 파일명 : 5350109-2001-0001-1122.jpg
# 인식 실행 중
# 정확도 : 84.41%
# 경과 시간 : 1.53초
#
# 파일명 : 5350109-2001-0001-1300.jpg
# 인식 실행 중
# 정확도 : 92.84%
# 경과 시간 : 2.47초
#
# 파일명 : 5350109-2001-0001-1301.jpg
# 인식 실행 중
# 정확도 : 93.48%
# 경과 시간 : 2.29초
#
# 파일명 : 5350109-2001-0001-1302.jpg
# 인식 실행 중
# 정확도 : 88.69%
# 경과 시간 : 3.09초
#
# 파일명 : 5350109-2001-0001-1303.jpg
# 인식 실행 중
# 정확도 : 81.89%
# 경과 시간 : 1.24초
#
# 파일명 : 5350109-2001-0001-1307.jpg
# 인식 실행 중
# 정확도 : 96.68%
# 경과 시간 : 3.62초
#
# 파일명 : 5350109-2001-0001-1310.jpg
# 인식 실행 중
# 정확도 : 94.55%
# 경과 시간 : 4.57초
#
# 파일명 : 5350109-2001-0001-1311.jpg
# 인식 실행 중
# 정확도 : 96.30%
# 경과 시간 : 1.18초
#
# 파일명 : 5350109-2001-0001-1419.jpg
# 인식 실행 중
# 정확도 : 96.17%
# 경과 시간 : 4.22초
#
# 파일명 : 5350109-2001-0001-1420.jpg
# 인식 실행 중
# 정확도 : 83.42%
# 경과 시간 : 1.13초
#
# 파일명 : 5350109-2001-0001-1421.jpg
# 인식 실행 중
# 정확도 : 96.16%
# 경과 시간 : 2.59초
#
# 파일명 : 5350109-2001-0001-1422.jpg
# 인식 실행 중
# 정확도 : 87.67%
# 경과 시간 : 1.87초
#
# 파일명 : 5350109-2001-0001-1424.jpg
# 인식 실행 중
# 정확도 : 90.65%
# 경과 시간 : 2.30초
#
# 파일명 : 5350109-2001-0001-1425.jpg
# 인식 실행 중
# 정확도 : 76.47%
# 경과 시간 : 1.03초
#
# 파일명 : 5350109-2001-0001-1517.jpg
# 인식 실행 중
# 정확도 : 92.81%
# 경과 시간 : 1.42초
#
# 파일명 : 5350109-2001-0001-1518.jpg
# 인식 실행 중
# 정확도 : 95.25%
# 경과 시간 : 2.38초
#
# 파일명 : 5350109-2001-0001-1519.jpg
# 인식 실행 중
# 정확도 : 94.37%
# 경과 시간 : 3.14초
#
# 파일명 : 5350109-2001-0001-1520.jpg
# 인식 실행 중
# 정확도 : 88.40%
# 경과 시간 : 2.58초
#
# 파일명 : 5350109-2001-0001-1521.jpg
# 인식 실행 중
# 정확도 : 80.93%
# 경과 시간 : 1.25초
#
# 파일명 : 5350109-2001-0001-1540.jpg
# 인식 실행 중
# 정확도 : 92.54%
# 경과 시간 : 1.73초
#
# 파일명 : 5350109-2001-0001-1542.jpg
# 인식 실행 중
# 정확도 : 95.30%
# 경과 시간 : 3.43초
#
# 파일명 : 5350109-2001-0001-1545.jpg
# 인식 실행 중
# 정확도 : 95.29%
# 경과 시간 : 2.82초
#
# 파일명 : 5350109-2001-0001-1546.jpg
# 인식 실행 중
# 정확도 : 82.55%
# 경과 시간 : 2.13초
#
# 파일명 : 5350109-2001-0001-1548.jpg
# 인식 실행 중
# 정확도 : 93.70%
# 경과 시간 : 1.98초
#
# 파일명 : 5350109-2001-0001-1549.jpg
# 인식 실행 중
# 정확도 : 94.73%
# 경과 시간 : 2.33초
#
# 파일명 : 5350109-2001-0001-1550.jpg
# 인식 실행 중
# 정확도 : 91.05%
# 경과 시간 : 2.77초
#
# 파일명 : 5350109-2001-0001-1551.jpg
# 인식 실행 중
# 정확도 : 81.62%
# 경과 시간 : 2.58초
#
# <테스트 총 결과>
# 총 데이터 수 : 200개
# 총 소요 시간 : 8분 14초
# 평균 인식 시간 : 2.47초
# 평균 정확도 : 91.13%

# %% [markdown]
# ## detect
# 속도 측정 / 결과물 저장

# %%
import easyocr
import json
import os
import time

import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image

# 폴더 경로
folder_path_source = '2001_source'
folder_path_label = '2001_label'

# 폴더 안에 있는 모든 파일을 리스트 형태로 가져오기
file_list = os.listdir(folder_path_source)

# 파일 경로와 파일 이름 결합
file_paths = [os.path.join(folder_path_source, file_name) for file_name in file_list]

# 파일 수와 평균 경과 시간, 평균 정확도를 저장할 변수 초기화
file_count = len(file_paths)
total_elapsed_time = 0
total_accuracy = 0

'''
# 파일 개수 지정 (ex) 1개)
file_paths = file_paths[:1]
file_count = 1
'''

# easyocr 모델 로드
reader = easyocr.Reader(['ko','en'], gpu=True)

# 각 파일에 대해 OCR 수행
for file_path in file_paths:
    filename_split = os.path.splitext(os.path.basename(file_path))[0]
    print("파일명 :", os.path.basename(file_path))
    print("인식 실행 중")
    
    # 시작 시간 저장
    start_time = time.time()
    
    # OCR 인식 결과 추출
    result = reader.detect(folder_path_source+"/"+filename_split+".jpg")
    
    # 인식 경과 시간 계산
    elapsed_time = time.time() - start_time
    
    # 총 경과 시간 계산
    total_elapsed_time += elapsed_time
    
    '''
    # 문자 인식 결과 출력
    print("")
    print("<EasyOCR 문자 영역 인식 결과>")
    print(result)
    '''
    
    # 라벨링 데이터(json) 파일 불러오기
    with open(folder_path_label+"/"+filename_split+".json", encoding="UTF8") as file:
        data = json.load(file)
        json_test = data['annotations']
        
        '''
        # 라벨링 데이터의 좌표 값만 출력
        print("")
        print("<라벨링 데이터>")
        for k in json_test:
            print(k['annotation.bbox'])
        '''
            
    # 경과 시간 출력
    print("경과 시간 : {:.2f}초".format(elapsed_time))
    print("")
    
    # 인식 결과 출력
    img = cv2.imread(folder_path_source+"/"+filename_split+".jpg")

    img = Image.fromarray(img)    # 이미지에 그리기 위해서 CV2 이미지를 PIL 이미지 객체로 변환
    draw = ImageDraw.Draw(img)

    np.random.seed(42)
    COLORS = np.random.randint(0, 255, size=(255, 3),dtype="uint8")

    # result의 좌표 값 슬라이싱
    for sublist in result[0]:
        coordinate = sublist[:]

    for i in coordinate :
        # 이미지 좌표 변수 지정
        x = i[0]
        y = i[2] 
        w = i[1] - i[0]
        h = i[3] - i[2]
    
        # 랜덤 색상 지정
        color_idx = random.randint(0,254)
        color = [int(c) for c in COLORS[color_idx]]

        # 이미지에 인식 영역 / 인식 문자 출력
        draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2)
        
    '''
    plt.figure(figsize=(50,50))
    plt.imshow(img)
    plt.show()
    '''
    
    img.save('ResultImage_detect/'+filename_split+'_result(detect).jpg')  # JPG 형식으로 저장

# 총 데이터 수 및 총 소요시간, 평균 경과 시간 계산
average_elapsed_time = total_elapsed_time / file_count
total_minutes = int(total_elapsed_time // 60)
total_seconds = int(total_elapsed_time % 60)

# 테스트 결과 출력
print("<테스트 총 결과>")
print("총 데이터 수 : "+str(file_count)+"개")
print("총 소요 시간 : "+str(total_minutes)+"분 "+str(total_seconds)+"초")
print("평균 인식 시간 : {:.2f}초".format(average_elapsed_time))
# Out:
# 파일명 : 5350109-2001-0001-0001.jpg
# 인식 실행 중
# 경과 시간 : 2.05초
#
# 파일명 : 5350109-2001-0001-0002.jpg
# 인식 실행 중
# 경과 시간 : 1.21초
#
# 파일명 : 5350109-2001-0001-0004.jpg
# 인식 실행 중
# 경과 시간 : 1.53초
#
# 파일명 : 5350109-2001-0001-0005.jpg
# 인식 실행 중
# 경과 시간 : 1.80초
#
# 파일명 : 5350109-2001-0001-0006.jpg
# 인식 실행 중
# 경과 시간 : 1.12초
#
# 파일명 : 5350109-2001-0001-0009.jpg
# 인식 실행 중
# 경과 시간 : 1.61초
#
# 파일명 : 5350109-2001-0001-0010.jpg
# 인식 실행 중
# 경과 시간 : 1.45초
#
# 파일명 : 5350109-2001-0001-0015.jpg
# 인식 실행 중
# 경과 시간 : 2.01초
#
# 파일명 : 5350109-2001-0001-0016.jpg
# 인식 실행 중
# 경과 시간 : 2.05초
#
# 파일명 : 5350109-2001-0001-0017.jpg
# 인식 실행 중
# 경과 시간 : 1.90초
#
# 파일명 : 5350109-2001-0001-0018.jpg
# 인식 실행 중
# 경과 시간 : 2.07초
#
# 파일명 : 5350109-2001-0001-0019.jpg
# 인식 실행 중
# 경과 시간 : 0.94초
#
# 파일명 : 5350109-2001-0001-0020.jpg
# 인식 실행 중
# 경과 시간 : 4.12초
#
# 파일명 : 5350109-2001-0001-0021.jpg
# 인식 실행 중
# 경과 시간 : 1.34초
#
# 파일명 : 5350109-2001-0001-0022.jpg
# 인식 실행 중
# 경과 시간 : 2.20초
#
# 파일명 : 5350109-2001-0001-0023.jpg
# 인식 실행 중
# 경과 시간 : 2.77초
#
# 파일명 : 5350109-2001-0001-0024.jpg
# 인식 실행 중
# 경과 시간 : 1.26초
#
# 파일명 : 5350109-2001-0001-0028.jpg
# 인식 실행 중
# 경과 시간 : 2.51초
#
# 파일명 : 5350109-2001-0001-0029.jpg
# 인식 실행 중
# 경과 시간 : 0.93초
#
# 파일명 : 5350109-2001-0001-0030.jpg
# 인식 실행 중
# 경과 시간 : 1.88초
#
# 파일명 : 5350109-2001-0001-0031.jpg
# 인식 실행 중
# 경과 시간 : 1.35초
#
# 파일명 : 5350109-2001-0001-0033.jpg
# 인식 실행 중
# 경과 시간 : 0.91초
#
# 파일명 : 5350109-2001-0001-0034.jpg
# 인식 실행 중
# 경과 시간 : 2.61초
#
# 파일명 : 5350109-2001-0001-0035.jpg
# 인식 실행 중
# 경과 시간 : 1.29초
#
# 파일명 : 5350109-2001-0001-0036.jpg
# 인식 실행 중
# 경과 시간 : 1.96초
#
# 파일명 : 5350109-2001-0001-0038.jpg
# 인식 실행 중
# 경과 시간 : 1.79초
#
# 파일명 : 5350109-2001-0001-0039.jpg
# 인식 실행 중
# 경과 시간 : 2.26초
#
# 파일명 : 5350109-2001-0001-0040.jpg
# 인식 실행 중
# 경과 시간 : 3.75초
#
# 파일명 : 5350109-2001-0001-0041.jpg
# 인식 실행 중
# 경과 시간 : 1.07초
#
# 파일명 : 5350109-2001-0001-0042.jpg
# 인식 실행 중
# 경과 시간 : 1.92초
#
# 파일명 : 5350109-2001-0001-0043.jpg
# 인식 실행 중
# 경과 시간 : 1.40초
#
# 파일명 : 5350109-2001-0001-0044.jpg
# 인식 실행 중
# 경과 시간 : 2.33초
#
# 파일명 : 5350109-2001-0001-0045.jpg
# 인식 실행 중
# 경과 시간 : 1.18초
#
# 파일명 : 5350109-2001-0001-0049.jpg
# 인식 실행 중
# 경과 시간 : 1.36초
#
# 파일명 : 5350109-2001-0001-0050.jpg
# 인식 실행 중
# 경과 시간 : 1.64초
#
# 파일명 : 5350109-2001-0001-0101.jpg
# 인식 실행 중
# 경과 시간 : 1.47초
#
# 파일명 : 5350109-2001-0001-0102.jpg
# 인식 실행 중
# 경과 시간 : 1.10초
#
# 파일명 : 5350109-2001-0001-0103.jpg
# 인식 실행 중
# 경과 시간 : 1.78초
#
# 파일명 : 5350109-2001-0001-0104.jpg
# 인식 실행 중
# 경과 시간 : 1.84초
#
# 파일명 : 5350109-2001-0001-0105.jpg
# 인식 실행 중
# 경과 시간 : 0.80초
#
# 파일명 : 5350109-2001-0001-0106.jpg
# 인식 실행 중
# 경과 시간 : 2.44초
#
# 파일명 : 5350109-2001-0001-0107.jpg
# 인식 실행 중
# 경과 시간 : 1.29초
#
# 파일명 : 5350109-2001-0001-0118.jpg
# 인식 실행 중
# 경과 시간 : 2.23초
#
# 파일명 : 5350109-2001-0001-0119.jpg
# 인식 실행 중
# 경과 시간 : 1.66초
#
# 파일명 : 5350109-2001-0001-0120.jpg
# 인식 실행 중
# 경과 시간 : 2.50초
#
# 파일명 : 5350109-2001-0001-0121.jpg
# 인식 실행 중
# 경과 시간 : 2.42초
#
# 파일명 : 5350109-2001-0001-0122.jpg
# 인식 실행 중
# 경과 시간 : 1.44초
#
# 파일명 : 5350109-2001-0001-0123.jpg
# 인식 실행 중
# 경과 시간 : 1.50초
#
# 파일명 : 5350109-2001-0001-0124.jpg
# 인식 실행 중
# 경과 시간 : 0.82초
#
# 파일명 : 5350109-2001-0001-0125.jpg
# 인식 실행 중
# 경과 시간 : 1.82초
#
# 파일명 : 5350109-2001-0001-0126.jpg
# 인식 실행 중
# 경과 시간 : 1.69초
#
# 파일명 : 5350109-2001-0001-0129.jpg
# 인식 실행 중
# 경과 시간 : 2.06초
#
# 파일명 : 5350109-2001-0001-0130.jpg
# 인식 실행 중
# 경과 시간 : 1.70초
#
# 파일명 : 5350109-2001-0001-0131.jpg
# 인식 실행 중
# 경과 시간 : 1.54초
#
# 파일명 : 5350109-2001-0001-0132.jpg
# 인식 실행 중
# 경과 시간 : 1.17초
#
# 파일명 : 5350109-2001-0001-0133.jpg
# 인식 실행 중
# 경과 시간 : 2.26초
#
# 파일명 : 5350109-2001-0001-0134.jpg
# 인식 실행 중
# 경과 시간 : 2.29초
#
# 파일명 : 5350109-2001-0001-0135.jpg
# 인식 실행 중
# 경과 시간 : 1.85초
#
# 파일명 : 5350109-2001-0001-0136.jpg
# 인식 실행 중
# 경과 시간 : 1.96초
#
# 파일명 : 5350109-2001-0001-0137.jpg
# 인식 실행 중
# 경과 시간 : 4.24초
#
# 파일명 : 5350109-2001-0001-0138.jpg
# 인식 실행 중
# 경과 시간 : 1.51초
#
# 파일명 : 5350109-2001-0001-0139.jpg
# 인식 실행 중
# 경과 시간 : 3.36초
#
# 파일명 : 5350109-2001-0001-0140.jpg
# 인식 실행 중
# 경과 시간 : 1.68초
#
# 파일명 : 5350109-2001-0001-0141.jpg
# 인식 실행 중
# 경과 시간 : 1.81초
#
# 파일명 : 5350109-2001-0001-0144.jpg
# 인식 실행 중
# 경과 시간 : 2.77초
#
# 파일명 : 5350109-2001-0001-0145.jpg
# 인식 실행 중
# 경과 시간 : 2.58초
#
# 파일명 : 5350109-2001-0001-0147.jpg
# 인식 실행 중
# 경과 시간 : 2.29초
#
# 파일명 : 5350109-2001-0001-0155.jpg
# 인식 실행 중
# 경과 시간 : 2.38초
#
# 파일명 : 5350109-2001-0001-0156.jpg
# 인식 실행 중
# 경과 시간 : 2.94초
#
# 파일명 : 5350109-2001-0001-0157.jpg
# 인식 실행 중
# 경과 시간 : 1.41초
#
# 파일명 : 5350109-2001-0001-0170.jpg
# 인식 실행 중
# 경과 시간 : 2.39초
#
# 파일명 : 5350109-2001-0001-0171.jpg
# 인식 실행 중
# 경과 시간 : 3.14초
#
# 파일명 : 5350109-2001-0001-0172.jpg
# 인식 실행 중
# 경과 시간 : 2.34초
#
# 파일명 : 5350109-2001-0001-0173.jpg
# 인식 실행 중
# 경과 시간 : 2.30초
#
# 파일명 : 5350109-2001-0001-0223.jpg
# 인식 실행 중
# 경과 시간 : 2.28초
#
# 파일명 : 5350109-2001-0001-0224.jpg
# 인식 실행 중
# 경과 시간 : 1.69초
#
# 파일명 : 5350109-2001-0001-0225.jpg
# 인식 실행 중
# 경과 시간 : 2.68초
#
# 파일명 : 5350109-2001-0001-0227.jpg
# 인식 실행 중
# 경과 시간 : 2.09초
#
# 파일명 : 5350109-2001-0001-0228.jpg
# 인식 실행 중
# 경과 시간 : 0.88초
#
# 파일명 : 5350109-2001-0001-0230.jpg
# 인식 실행 중
# 경과 시간 : 1.56초
#
# 파일명 : 5350109-2001-0001-0231.jpg
# 인식 실행 중
# 경과 시간 : 1.16초
#
# 파일명 : 5350109-2001-0001-0235.jpg
# 인식 실행 중
# 경과 시간 : 1.85초
#
# 파일명 : 5350109-2001-0001-0239.jpg
# 인식 실행 중
# 경과 시간 : 1.79초
#
# 파일명 : 5350109-2001-0001-0240.jpg
# 인식 실행 중
# 경과 시간 : 1.31초
#
# 파일명 : 5350109-2001-0001-0241.jpg
# 인식 실행 중
# 경과 시간 : 2.38초
#
# 파일명 : 5350109-2001-0001-0242.jpg
# 인식 실행 중
# 경과 시간 : 2.54초
#
# 파일명 : 5350109-2001-0001-0244.jpg
# 인식 실행 중
# 경과 시간 : 1.47초
#
# 파일명 : 5350109-2001-0001-0245.jpg
# 인식 실행 중
# 경과 시간 : 0.81초
#
# 파일명 : 5350109-2001-0001-0249.jpg
# 인식 실행 중
# 경과 시간 : 1.24초
#
# 파일명 : 5350109-2001-0001-0250.jpg
# 인식 실행 중
# 경과 시간 : 1.45초
#
# 파일명 : 5350109-2001-0001-0251.jpg
# 인식 실행 중
# 경과 시간 : 1.10초
#
# 파일명 : 5350109-2001-0001-0252.jpg
# 인식 실행 중
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0333.jpg
# 인식 실행 중
# 경과 시간 : 2.11초
#
# 파일명 : 5350109-2001-0001-0334.jpg
# 인식 실행 중
# 경과 시간 : 1.11초
#
# 파일명 : 5350109-2001-0001-0340.jpg
# 인식 실행 중
# 경과 시간 : 1.39초
#
# 파일명 : 5350109-2001-0001-0341.jpg
# 인식 실행 중
# 경과 시간 : 1.67초
#
# 파일명 : 5350109-2001-0001-0342.jpg
# 인식 실행 중
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0343.jpg
# 인식 실행 중
# 경과 시간 : 2.78초
#
# 파일명 : 5350109-2001-0001-0344.jpg
# 인식 실행 중
# 경과 시간 : 1.10초
#
# 파일명 : 5350109-2001-0001-0345.jpg
# 인식 실행 중
# 경과 시간 : 2.05초
#
# 파일명 : 5350109-2001-0001-0355.jpg
# 인식 실행 중
# 경과 시간 : 1.43초
#
# 파일명 : 5350109-2001-0001-0356.jpg
# 인식 실행 중
# 경과 시간 : 3.50초
#
# 파일명 : 5350109-2001-0001-0357.jpg
# 인식 실행 중
# 경과 시간 : 1.38초
#
# 파일명 : 5350109-2001-0001-0358.jpg
# 인식 실행 중
# 경과 시간 : 1.54초
#
# 파일명 : 5350109-2001-0001-0359.jpg
# 인식 실행 중
# 경과 시간 : 0.81초
#
# 파일명 : 5350109-2001-0001-0360.jpg
# 인식 실행 중
# 경과 시간 : 2.02초
#
# 파일명 : 5350109-2001-0001-0361.jpg
# 인식 실행 중
# 경과 시간 : 0.92초
#
# 파일명 : 5350109-2001-0001-0362.jpg
# 인식 실행 중
# 경과 시간 : 2.20초
#
# 파일명 : 5350109-2001-0001-0363.jpg
# 인식 실행 중
# 경과 시간 : 2.26초
#
# 파일명 : 5350109-2001-0001-0364.jpg
# 인식 실행 중
# 경과 시간 : 1.43초
#
# 파일명 : 5350109-2001-0001-0366.jpg
# 인식 실행 중
# 경과 시간 : 1.69초
#
# 파일명 : 5350109-2001-0001-0367.jpg
# 인식 실행 중
# 경과 시간 : 1.09초
#
# 파일명 : 5350109-2001-0001-0455.jpg
# 인식 실행 중
# 경과 시간 : 2.33초
#
# 파일명 : 5350109-2001-0001-0456.jpg
# 인식 실행 중
# 경과 시간 : 0.84초
#
# 파일명 : 5350109-2001-0001-0457.jpg
# 인식 실행 중
# 경과 시간 : 2.06초
#
# 파일명 : 5350109-2001-0001-0458.jpg
# 인식 실행 중
# 경과 시간 : 1.19초
#
# 파일명 : 5350109-2001-0001-0460.jpg
# 인식 실행 중
# 경과 시간 : 1.68초
#
# 파일명 : 5350109-2001-0001-0461.jpg
# 인식 실행 중
# 경과 시간 : 0.88초
#
# 파일명 : 5350109-2001-0001-0464.jpg
# 인식 실행 중
# 경과 시간 : 1.89초
#
# 파일명 : 5350109-2001-0001-0465.jpg
# 인식 실행 중
# 경과 시간 : 3.40초
#
# 파일명 : 5350109-2001-0001-0466.jpg
# 인식 실행 중
# 경과 시간 : 2.05초
#
# 파일명 : 5350109-2001-0001-0467.jpg
# 인식 실행 중
# 경과 시간 : 1.82초
#
# 파일명 : 5350109-2001-0001-0468.jpg
# 인식 실행 중
# 경과 시간 : 0.89초
#
# 파일명 : 5350109-2001-0001-0469.jpg
# 인식 실행 중
# 경과 시간 : 2.01초
#
# 파일명 : 5350109-2001-0001-0470.jpg
# 인식 실행 중
# 경과 시간 : 1.85초
#
# 파일명 : 5350109-2001-0001-0471.jpg
# 인식 실행 중
# 경과 시간 : 0.86초
#
# 파일명 : 5350109-2001-0001-0472.jpg
# 인식 실행 중
# 경과 시간 : 2.37초
#
# 파일명 : 5350109-2001-0001-0473.jpg
# 인식 실행 중
# 경과 시간 : 1.22초
#
# 파일명 : 5350109-2001-0001-0479.jpg
# 인식 실행 중
# 경과 시간 : 1.69초
#
# 파일명 : 5350109-2001-0001-0480.jpg
# 인식 실행 중
# 경과 시간 : 0.82초
#
# 파일명 : 5350109-2001-0001-0481.jpg
# 인식 실행 중
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-0482.jpg
# 인식 실행 중
# 경과 시간 : 1.76초
#
# 파일명 : 5350109-2001-0001-0483.jpg
# 인식 실행 중
# 경과 시간 : 0.70초
#
# 파일명 : 5350109-2001-0001-0484.jpg
# 인식 실행 중
# 경과 시간 : 1.68초
#
# 파일명 : 5350109-2001-0001-0485.jpg
# 인식 실행 중
# 경과 시간 : 0.80초
#
# 파일명 : 5350109-2001-0001-0598.jpg
# 인식 실행 중
# 경과 시간 : 1.67초
#
# 파일명 : 5350109-2001-0001-0599.jpg
# 인식 실행 중
# 경과 시간 : 2.55초
#
# 파일명 : 5350109-2001-0001-0600.jpg
# 인식 실행 중
# 경과 시간 : 3.13초
#
# 파일명 : 5350109-2001-0001-0601.jpg
# 인식 실행 중
# 경과 시간 : 1.21초
#
# 파일명 : 5350109-2001-0001-0602.jpg
# 인식 실행 중
# 경과 시간 : 2.09초
#
# 파일명 : 5350109-2001-0001-0603.jpg
# 인식 실행 중
# 경과 시간 : 1.09초
#
# 파일명 : 5350109-2001-0001-0604.jpg
# 인식 실행 중
# 경과 시간 : 1.59초
#
# 파일명 : 5350109-2001-0001-0616.jpg
# 인식 실행 중
# 경과 시간 : 1.83초
#
# 파일명 : 5350109-2001-0001-0617.jpg
# 인식 실행 중
# 경과 시간 : 1.15초
#
# 파일명 : 5350109-2001-0001-0618.jpg
# 인식 실행 중
# 경과 시간 : 1.80초
#
# 파일명 : 5350109-2001-0001-0619.jpg
# 인식 실행 중
# 경과 시간 : 0.77초
#
# 파일명 : 5350109-2001-0001-0620.jpg
# 인식 실행 중
# 경과 시간 : 1.93초
#
# 파일명 : 5350109-2001-0001-0621.jpg
# 인식 실행 중
# 경과 시간 : 0.91초
#
# 파일명 : 5350109-2001-0001-0715.jpg
# 인식 실행 중
# 경과 시간 : 1.96초
#
# 파일명 : 5350109-2001-0001-0716.jpg
# 인식 실행 중
# 경과 시간 : 1.85초
#
# 파일명 : 5350109-2001-0001-0717.jpg
# 인식 실행 중
# 경과 시간 : 1.34초
#
# 파일명 : 5350109-2001-0001-0718.jpg
# 인식 실행 중
# 경과 시간 : 1.91초
#
# 파일명 : 5350109-2001-0001-0719.jpg
# 인식 실행 중
# 경과 시간 : 3.26초
#
# 파일명 : 5350109-2001-0001-0720.jpg
# 인식 실행 중
# 경과 시간 : 1.46초
#
# 파일명 : 5350109-2001-0001-0721.jpg
# 인식 실행 중
# 경과 시간 : 2.18초
#
# 파일명 : 5350109-2001-0001-0722.jpg
# 인식 실행 중
# 경과 시간 : 1.41초
#
# 파일명 : 5350109-2001-0001-0724.jpg
# 인식 실행 중
# 경과 시간 : 1.87초
#
# 파일명 : 5350109-2001-0001-0727.jpg
# 인식 실행 중
# 경과 시간 : 0.69초
#
# 파일명 : 5350109-2001-0001-1088.jpg
# 인식 실행 중
# 경과 시간 : 2.08초
#
# 파일명 : 5350109-2001-0001-1089.jpg
# 인식 실행 중
# 경과 시간 : 0.94초
#
# 파일명 : 5350109-2001-0001-1090.jpg
# 인식 실행 중
# 경과 시간 : 1.83초
#
# 파일명 : 5350109-2001-0001-1102.jpg
# 인식 실행 중
# 경과 시간 : 1.67초
#
# 파일명 : 5350109-2001-0001-1103.jpg
# 인식 실행 중
# 경과 시간 : 1.08초
#
# 파일명 : 5350109-2001-0001-1104.jpg
# 인식 실행 중
# 경과 시간 : 2.10초
#
# 파일명 : 5350109-2001-0001-1105.jpg
# 인식 실행 중
# 경과 시간 : 1.55초
#
# 파일명 : 5350109-2001-0001-1112.jpg
# 인식 실행 중
# 경과 시간 : 1.69초
#
# 파일명 : 5350109-2001-0001-1113.jpg
# 인식 실행 중
# 경과 시간 : 0.84초
#
# 파일명 : 5350109-2001-0001-1114.jpg
# 인식 실행 중
# 경과 시간 : 1.64초
#
# 파일명 : 5350109-2001-0001-1115.jpg
# 인식 실행 중
# 경과 시간 : 0.69초
#
# 파일명 : 5350109-2001-0001-1116.jpg
# 인식 실행 중
# 경과 시간 : 1.88초
#
# 파일명 : 5350109-2001-0001-1117.jpg
# 인식 실행 중
# 경과 시간 : 2.42초
#
# 파일명 : 5350109-2001-0001-1120.jpg
# 인식 실행 중
# 경과 시간 : 3.12초
#
# 파일명 : 5350109-2001-0001-1121.jpg
# 인식 실행 중
# 경과 시간 : 1.05초
#
# 파일명 : 5350109-2001-0001-1122.jpg
# 인식 실행 중
# 경과 시간 : 1.20초
#
# 파일명 : 5350109-2001-0001-1300.jpg
# 인식 실행 중
# 경과 시간 : 1.64초
#
# 파일명 : 5350109-2001-0001-1301.jpg
# 인식 실행 중
# 경과 시간 : 1.34초
#
# 파일명 : 5350109-2001-0001-1302.jpg
# 인식 실행 중
# 경과 시간 : 2.01초
#
# 파일명 : 5350109-2001-0001-1303.jpg
# 인식 실행 중
# 경과 시간 : 1.30초
#
# 파일명 : 5350109-2001-0001-1307.jpg
# 인식 실행 중
# 경과 시간 : 1.48초
#
# 파일명 : 5350109-2001-0001-1310.jpg
# 인식 실행 중
# 경과 시간 : 1.65초
#
# 파일명 : 5350109-2001-0001-1311.jpg
# 인식 실행 중
# 경과 시간 : 1.23초
#
# 파일명 : 5350109-2001-0001-1419.jpg
# 인식 실행 중
# 경과 시간 : 1.96초
#
# 파일명 : 5350109-2001-0001-1420.jpg
# 인식 실행 중
# 경과 시간 : 0.88초
#
# 파일명 : 5350109-2001-0001-1421.jpg
# 인식 실행 중
# 경과 시간 : 1.79초
#
# 파일명 : 5350109-2001-0001-1422.jpg
# 인식 실행 중
# 경과 시간 : 0.90초
#
# 파일명 : 5350109-2001-0001-1424.jpg
# 인식 실행 중
# 경과 시간 : 1.95초
#
# 파일명 : 5350109-2001-0001-1425.jpg
# 인식 실행 중
# 경과 시간 : 0.69초
#
# 파일명 : 5350109-2001-0001-1517.jpg
# 인식 실행 중
# 경과 시간 : 2.22초
#
# 파일명 : 5350109-2001-0001-1518.jpg
# 인식 실행 중
# 경과 시간 : 3.36초
#
# 파일명 : 5350109-2001-0001-1519.jpg
# 인식 실행 중
# 경과 시간 : 1.74초
#
# 파일명 : 5350109-2001-0001-1520.jpg
# 인식 실행 중
# 경과 시간 : 1.62초
#
# 파일명 : 5350109-2001-0001-1521.jpg
# 인식 실행 중
# 경과 시간 : 1.60초
#
# 파일명 : 5350109-2001-0001-1540.jpg
# 인식 실행 중
# 경과 시간 : 1.19초
#
# 파일명 : 5350109-2001-0001-1542.jpg
# 인식 실행 중
# 경과 시간 : 1.55초
#
# 파일명 : 5350109-2001-0001-1545.jpg
# 인식 실행 중
# 경과 시간 : 1.94초
#
# 파일명 : 5350109-2001-0001-1546.jpg
# 인식 실행 중
# 경과 시간 : 1.48초
#
# 파일명 : 5350109-2001-0001-1548.jpg
# 인식 실행 중
# 경과 시간 : 1.15초
#
# 파일명 : 5350109-2001-0001-1549.jpg
# 인식 실행 중
# 경과 시간 : 2.13초
#
# 파일명 : 5350109-2001-0001-1550.jpg
# 인식 실행 중
# 경과 시간 : 1.56초
#
# 파일명 : 5350109-2001-0001-1551.jpg
# 인식 실행 중
# 경과 시간 : 1.64초
#
# <테스트 총 결과>
# 총 데이터 수 : 200개
# 총 소요 시간 : 5분 50초
# 평균 인식 시간 : 1.75초

# %% [markdown]
# ## 결과 분석
# readtext = 평균 2.07초 / 문자 인식 정확도 : 90% 대
#
# detect = 평균 1.75초
