# %%
# !pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\82109\anaconda3\lib\site-packages (8.2.0)
# Requirement already satisfied: backcall in c:\users\82109\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: decorator in c:\users\82109\anaconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\82109\anaconda3\lib\site-packages (from IPython) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\82109\anaconda3\lib\site-packages (from IPython) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\82109\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\82109\anaconda3\lib\site-packages (from IPython) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\82109\anaconda3\lib\site-packages (from IPython) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\82109\anaconda3\lib\site-packages (from IPython) (67.6.1)
# Requirement already satisfied: stack-data in c:\users\82109\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\82109\anaconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: colorama in c:\users\82109\anaconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\82109\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\82109\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: executing in c:\users\82109\anaconda3\lib\site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\82109\anaconda3\lib\site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\82109\anaconda3\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six in c:\users\82109\anaconda3\lib\site-packages (from asttokens->stack-data->IPython) (1.16.0)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\82109\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\82109\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\82109\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\82109\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # ipynb to py
# pip install nbconvert로 변환툴 설치

# %%
from IPython.display import Image
Image("1.jpg")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 파이썬 exe 파일
# pip install -U pyinstaller 로 설치

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 오류가 나서 py 대신 ipynb로 돌려보았습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
