# %%
# !git clone https://github.com/clovaai/deep-text-recognition-benchmark.git
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 495, done.
# remote: Total 495 (delta 0), reused 0 (delta 0), pack-reused 495
# Receiving objects: 100% (495/495), 3.07 MiB | 9.94 MiB/s, done.
# Resolving deltas: 100% (301/301), done.

# %%
# !pip3 install lmdb pillow torchvision nltk natsort
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# !python3 /content/drive/MyDrive/fine-tuning/deep-text-recognition-benchmark/train.py \
        --train_data "/content/drive/MyDrive/fine-tuning/lmdb/train" \
        --valid_data "/content/drive/MyDrive/fine-tuning/lmdb/val" \
        --select_data / \
        --batch_ratio 1 \
        --Transformation None \
        --FeatureExtraction "VGG" \
        --SequenceModeling "BiLSTM" \
        --Prediction "CTC" \
        --input_channel 1 \
        --output_channel 256 \
        --hidden_size 256 \
        --saved_model "/content/drive/MyDrive/fine-tuning/pre-model/korean_g2.pth" \
        --FT
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: /content/drive/MyDrive/fine-tuning/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    /content/drive/MyDrive/fine-tuning/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 13934
# num total samples of /: 13934 x 1.0 (total_data_usage_ratio) = 13934
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# ...
